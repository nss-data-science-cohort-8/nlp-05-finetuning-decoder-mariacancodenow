# %% [markdown]
# ## Decoder Finetuning Example
#
# In this notebook, you'll get to practice fine-tuning a generative model.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import Trainer, TrainingArguments
import torch
from torch.utils.data import Dataset
from peft import get_peft_model, LoraConfig, TaskType
import glob

# %% [markdown]
# For this example, we'll be working with the script of the first episode of Star Trek, the Next Generation.
#
# First, we'll read it in and do some minor cleanup.

# %%
with open("script.txt", "r", encoding="utf-8") as f:
    text = f.read()

lines = [line.strip() for line in text.split('\n') if len(line.strip()) > 10]
text = "\n".join(lines)
print(text[:1000])
# Out:
# STAR TREK: THE NEXT GENERATION
# "Encounter at Farpoint"
# D.C. Fontana
# Gene Roddenberry
# This script is not for publicaion or reproduction.
# No one is authorized to dispose of the same. If los t or
# destroyed, please notify the Script Department.
# FINAL DRAFT
# April 13, 1987
# 1    EXT. SPACE - STARSHIP (OPTICAL)
# The U.S.S. Enterprise NCC 1701-D traveling at warp  speed
# through space.
# PICARD V.O.
# Captain's log, stardate 42353.7.
# Our destination is planet Cygnus
# IV, beyond which lies the great
# unexplored mass of the galaxy.
# 2    OTHER INTRODUCTORY ANGLES (OPTICAL)
# on the gigantic new Enterprise NCC 1701-D.
# PICARD V.O.
# My orders are to examine Farpoint,
# a starbase built there by the
# inhabitants of that world.
# Meanwhile ...
# 3    INT. ENGINE ROOM
# Huge, with a giant wall diagram showing the immens ity
# of this Galaxy Class starship.
# PICARD V.O.
# (continuing)
# ... I am becoming better
# acquainted with my new command,
# this Galaxy Class U.S.S.
# Enterprise.
# 4    CLOSER ON VESSEL DIAGRAM
# Showing the details an

# %%
text = ''
file_list = glob.glob('Star Trek*.txt')
for file_path in file_list:
    with open(file_path, "r", encoding="utf-8") as f:
        text += f.read()

# %%
lines = [line.strip() for line in text.split('\n') if len(line.strip()) > 10]
text = "\n".join(lines)
print(text[:1000])
# Out:
# STAR TREK: THE NEXT GENERATION
# "Angel One"
# Patrick Barry
# Directed by
# Michael Rhodes
# Copyright 1987 Paramount Pictures Corporation. All Rights
# This script is not for publication or reproduction.  No one
# is authorized to dispose of same. If lost or destro yed,
# please notify the Script Department.
# REVISED FINAL DRAFT
# NOVEMBER 9, 1987
# STAR TREK: "Angel One" - 11/9/87 - C AST
# STAR TREK: THE NEXT GENERATION
# "Angel One"
# PICARD               BEATA
# RIKER                TRENT
# BEVERLY              ARIEL
# DATA                 RAMSEY
# WORF                 Non-Speaking R oles
# GEORDI                SEVERAL MALE SECRETARIES
# WESLEY                TWO TALL WOME N
# THREE MALE SU RVIVORS
# FEMALE GUARDS
# Non-Speaking Roles    TWO NATIVE WO MEN
# A BUDDY              NATIVE MEN
# TRANSPORTER OPERATOR
# CREWMEMBERS
# STAR TREK: "Angel One" - 11/9/87 - SETS
# STAR TREK: THE NEXT GENERATION
# "Angel One"
# INTERIORS                  EXTERIORS
# USS ENTERPRISE             USS ENTERPRI SE
# Main bridge
# Corridor                 ANGEL O

# %%
len(text)
# Out:
# 1373605

# %% [markdown]
# First, we need to create our tokenizer.
#
# **Part 1:** Create a tokenizer using "distilgpt2" with the [Autotokenizer.from_pretrained method](https://huggingface.co/docs/transformers/v4.52.3/en/model_doc/auto#transformers.AutoTokenizer).

# %%
tokenizer = AutoTokenizer.from_pretrained("distilgpt2")

# %% [markdown]
# During training, all sequences need to be the same lenght, so we need to set a padding token for shorter sequences. We'll use the end of sequence token for this.

# %%
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# **Part 2:** Use the [encode method](https://huggingface.co/docs/transformers/en/main_classes/tokenizer#transformers.PreTrainedTokenizer.encode) to encode the text. Make sure that this returns PyTorch tensors. Save

# %%
tokens = tokenizer.encode(text, return_tensors="pt")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (428937 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# Now, we'll split the text into shorter chunks.

# %%
tokens = tokens[0]

chunk_size = 128
chunks = [tokens[i:i+chunk_size] for i in range(0, len(tokens)-chunk_size, chunk_size)]

input_ids = torch.stack([torch.tensor(chunk) for chunk in chunks])
# Out:
# <ipython-input-71-c3085470c5b2>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_ids = torch.stack([torch.tensor(chunk) for chunk in chunks])

# %% [markdown]
# Here's a helper class for our training data.

# %%
class ScriptDataset(Dataset):
    def __init__(self, input_ids):
        self.input_ids = input_ids

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": torch.ones_like(self.input_ids[idx]),
            "labels": self.input_ids[idx],
        }

dataset = ScriptDataset(input_ids)

# %% [markdown]
# **Part 3:** Make a model named base_model by using the [AutoModelforCausalLM.from_pretrained method](https://huggingface.co/docs/transformers/en/model_doc/auto#transformers.AutoModelForCausalLM), using the pretrained distilgpt2 model.

# %%
base_model = AutoModelForCausalLM.from_pretrained("distilgpt2")

# %%
# Match the token_embeddings to the same for the tokenizer.
base_model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(50257, 768)

# %% [markdown]
# **Part 4:** We'll be finetuning our model using LoRA. Set up a LoraConfig object, lora_config, with rank 8, alpha of 32 and dropout of 0.1. Set the target_modules to ["c_attn"], the bias to "none", and the task_type to TaskType.CAUSAL_LM.
#
# Then, use the [get_peft_model function](https://huggingface.co/docs/peft/v0.15.0/en/package_reference/peft_model#peft.get_peft_model) to create a model using the config object. Save the results to an object named model.

# %%
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    lora_dropout=0.1,
    target_modules=["c_attn"],
    bias="none",
    task_type=TaskType.CAUSAL_LM)

model = get_peft_model(base_model, lora_config)
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/layer.py:1768: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(

# %% [markdown]
# We'll set up a Trainer object and call the train method.

# %%
num_train_epochs = 10

training_args = TrainingArguments(
    output_dir="./xfiles_distilgpt2_lora",
    per_device_train_batch_size=2,
    num_train_epochs=num_train_epochs,
    logging_steps=10,
    save_steps=50,
    warmup_steps=5,
    learning_rate=2e-4,
    save_total_limit=1,
    fp16=True,
    report_to="none",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    tokenizer=tokenizer,
)

trainer.train()
# Out:
# <ipython-input-76-4a05ffe3e150>:16: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='16760' max='16760' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16760/16760 09:35, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.562300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>4.721700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>4.389400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>4.526600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>4.560000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>4.454300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>4.360500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>4.418600</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>4.209700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>4.161700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>4.238500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>4.194800</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>4.115400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>4.254800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>4.308800</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>3.954800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>4.192800</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>3.976400</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>4.148600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.051700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>4.185800</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>4.215600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>4.005900</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>4.049100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>4.142800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>3.957000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>4.125500</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>3.953000</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>3.913900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>3.979000</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>4.123300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>3.997800</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>4.147200</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>3.966100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>4.218400</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>3.829200</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>3.868700</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>3.853400</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>3.977800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>4.113600</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>3.980900</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>3.832200</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>4.157100</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>3.810900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>3.868300</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>3.739500</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>3.923700</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>3.918600</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>3.635100</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>3.931000</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>3.846800</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>3.875300</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>3.830300</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>3.812400</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>4.007100</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>3.836000</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>3.867600</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>3.908100</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>3.765400</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>3.807400</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>3.983700</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>3.803500</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>4.050600</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>3.856800</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>3.709200</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>3.822700</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>3.596300</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>3.813700</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>4.097600</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>3.890000</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>3.797500</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>3.656800</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>3.749200</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>3.828600</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>3.861600</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>4.024800</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>4.042900</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>3.841800</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>3.816600</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>3.704500</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>3.838500</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>3.769500</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>3.645100</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>3.911400</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>3.666900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>3.898900</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>3.645300</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>3.804900</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>3.791400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>3.941900</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>3.847100</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>3.641700</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>3.906500</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>3.799300</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>3.819500</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>3.725500</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>3.902000</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>3.856800</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>3.768100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.616700</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>3.789800</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>3.799200</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>3.839800</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>3.754600</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>3.747000</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>3.911700</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>3.664900</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>3.900900</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>3.648400</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>3.746700</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>3.783200</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>3.851800</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>3.937100</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>3.677600</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>3.552500</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>3.795800</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>3.824700</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>3.499200</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>3.847400</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>3.791500</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>3.680100</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>3.672800</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>3.771100</td>
#     </tr>
#     <tr>
#       <
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py:4064: UserWarning: mtime may not be reliable on this filesystem, falling back to numerical ordering
#   warnings.warn("mtime may not be reliable on this filesystem, falling back to numerical ordering")
# TrainOutput(global_step=16760, training_loss=3.517369915136005, metrics={'train_runtime': 575.5681, 'train_samples_per_second': 58.221, 'train_steps_per_second': 29.119, 'total_flos': 1098301644472320.0, 'train_loss': 3.517369915136005, 'epoch': 10.0})

# %% [markdown]
# Before generating new text, let's ensure that we're using GPUs.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): GPT2LMHeadModel(
#       (transformer): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-5): 6 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2Attention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#       (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#     )
#   )
# )

# %% [markdown]
# Here's a helper function to generate new text, given a model.

# %%
def generate_text(model, prompt, tokenizer, device, max_new_tokens=100):
    model.eval()    # Ensures that we're generating, not training
    inputs = tokenizer(prompt, return_tensors="pt", padding=True).to(device)  # Tokenize the prompt
    output = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=max_new_tokens,
        do_sample=True,
        top_p=0.9,
        temperature=1.0,
        pad_token_id=tokenizer.eos_token_id
    )
    return tokenizer.decode(output[0], skip_special_tokens=True)  # The model generates tokens, so we need to decode those back to words

# %% [markdown]
# We'll load back in the base pretrained model for comparison.

# %%
base_model = AutoModelForCausalLM.from_pretrained("distilgpt2").to(device)
tokenizer = AutoTokenizer.from_pretrained("distilgpt2")
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# **Part 5:** Using the generate_text function, try out the prompt "PICARD" with both the pretrained distilgpt2 model (base_model), and the finetuned model. Try other prompts, too.

# %%
print(generate_text(base_model, "PICARD", tokenizer, device))
# Out:
# PICARDI: The National Defense Authorization Act of 1994, which provided that, on January 1, 1993, for the Defense of Marriage Act of 1996, the President would authorize the Armed Forces to carry out the following functions:

# %%
print(generate_text(model, "PICARD", tokenizer, device))
# Out:
# PICARDER, LIPER
# He looks at the camera as he looks on.
# (CONT'D)
# (CONT'D)
# Is it your fault?
# What's the fault?
# (CONT'D)
# They're talking about a
# spaghetti-eating planet.
# And that planet has to
# immediately
# take over.
# (CONT'D)
# And there is no question
# that it's
# solution,
# which will be necessary
# for all

# %%
print(generate_text(model, "PICARD", tokenizer, device))
# Out:
# PICARD LES ON OFF AND
# RIKER LAWS INTO the bridge and turns her to look at it.
# STAR TREK: "The Naked Now" - 2/21/88 - ACT TWO        38.
# 49   CONTINUED:
# (satisfaction)
# I've got the crew in charge
# and they're going to send you
# and their crew back.
# 49   INT. ENTERPRISE (OPTICAL)

# %% [markdown]
# **Bonus:** See what happens if you allow more training epochs. You've also been provided all of the scripts from season 1. How does the model do when given more examples?
